# %%
#!/usr/bin/env python3
import pandas as pd
import numpy as np
import datetime
from collections import defaultdict, Counter

# Configuration variables for Jupyter notebook
INPUT_FILE = "/home/smotaali/BGP_Traffic_Generation/results/bgp_updates_analysis_20251208_223239.csv"
OUTPUT_FILE = "/home/smotaali/BGP_Traffic_Generation/results/20251208_223239_exctracted_1s.csv"
WINDOW_SIZE = '1s'  # You can change to '30s', '5min', etc.
LABEL_STRATEGY = 'majority'  # Options: 'majority', 'conservative', 'weighted'

def calculate_edit_distance(as_path1, as_path2):
    """
    Calculate edit distance between two AS paths
    """
    if not as_path1 or not as_path2:
        return 0
    
    # Handle integer AS paths by converting them to single-item lists
    if isinstance(as_path1, int):
        as_path1 = [as_path1]
    
    if isinstance(as_path2, int):
        as_path2 = [as_path2]
    
    # Convert paths to lists if they are strings
    if isinstance(as_path1, str):
        # Handle cases with special characters
        as_path1 = as_path1.replace('{', '').replace('}', '')
        as_path1 = [int(as_num) for as_num in as_path1.split() if as_num.isdigit()]
    
    if isinstance(as_path2, str):
        # Handle cases with special characters
        as_path2 = as_path2.replace('{', '').replace('}', '')
        as_path2 = [int(as_num) for as_num in as_path2.split() if as_num.isdigit()]
    
    if not as_path1 or not as_path2:
        return 0
    
    m, n = len(as_path1), len(as_path2)
    
    # Initialize the distance matrix
    dp = [[0] * (n + 1) for _ in range(m + 1)]
    
    # Fill the first row and column
    for i in range(m + 1):
        dp[i][0] = i
    for j in range(n + 1):
        dp[0][j] = j
    
    # Calculate edit distance
    for i in range(1, m + 1):
        for j in range(1, n + 1):
            if as_path1[i-1] == as_path2[j-1]:
                dp[i][j] = dp[i-1][j-1]
            else:
                dp[i][j] = 1 + min(dp[i-1][j], dp[i][j-1], dp[i-1][j-1])
    
    return dp[m][n]
    

def extract_features(df_window):
    """
    Extract BGP features from a dataframe within a specific time window
    """
    features = {}
    

    # 1. ANNOUNCEMENTS
    # Count number of updates by type
    announcements = df_window[df_window['Subtype'] == 'ANNOUNCE']
    
    # 2. WITHDRAWALS - including all withdrawal types
    withdrawal_types = ['WITHDRAW', 'WITHDRAW_MP_UNREACH_NLRI_AFI2']
    withdrawals = df_window[df_window['Subtype'].isin(withdrawal_types)]
    
    # Store counts
    features['announcements'] = len(announcements)
    features['withdrawals'] = len(withdrawals)
    
    # 3. NLRI_ANN (Network Layer Reachability Information announcements)
    features['nlri_ann'] = features['announcements']
    
    # 4. DUPLICATES
    # Proper implementation for duplicates: same prefix announced repeatedly with the same attributes
    if not announcements.empty:
        # Group by all relevant attributes and count instances > 1
        dup_cols = ['Peer_IP', 'Peer_ASN', 'Prefix', 'AS_Path', 'Origin', 'Next_Hop', 'MED', 'Local_Pref', 'Communities']
        dup_cols = [col for col in dup_cols if col in announcements.columns]  # Only include columns that exist
        
        # Count announcements for same prefix/path/attributes
        announcement_counts = announcements.groupby(dup_cols).size()
        duplicates = sum(count - 1 for count in announcement_counts if count > 1)
        features['dups'] = duplicates
    else:
        features['dups'] = 0
    
    # 5-7. ORIGIN ATTRIBUTES
    # Only count origin attributes that are present in your data
    if not announcements.empty and 'Origin' in announcements.columns:
        origin_counts = announcements['Origin'].value_counts()
        features['origin_0'] = origin_counts.get('IGP', 0)  
      
        features['origin_2'] = origin_counts.get('INCOMPLETE', 0)  
        
        # 8. ORIGIN CHANGES
        # Count prefixes with more than one unique origin attribute
        if not announcements.empty:
            unique_prefix_origins = announcements.groupby('Prefix')['Origin'].nunique()
            features['origin_changes'] = (unique_prefix_origins > 1).sum()
        else:
            features['origin_changes'] = 0
    else:
        features['origin_0'] = 0
        features['origin_2'] = 0
        features['origin_changes'] = 0
    
    # 9-10. AS PATH METRICS
    if not announcements.empty and 'AS_Path' in announcements.columns:
        # Filter out empty AS paths
        valid_as_paths = announcements[announcements['AS_Path'].notna() & (announcements['AS_Path'] != '')]
        
        if not valid_as_paths.empty:
            # Calculate AS path lengths
            as_path_lengths = valid_as_paths['AS_Path'].apply(
                lambda path: len([p for p in path.split() if p.isdigit()]) if isinstance(path, str) else 0
            )
            
            # 9. AS_PATH_MAX: Maximum AS path length
            features['as_path_max'] = as_path_lengths.max() if not as_path_lengths.empty else 0
            
            # 10. UNIQUE_AS_PATH_MAX: Maximum number of unique AS paths per prefix
            unique_paths_per_prefix = valid_as_paths.groupby('Prefix')['AS_Path'].nunique()
            features['unique_as_path_max'] = unique_paths_per_prefix.max() if not unique_paths_per_prefix.empty else 0
            
            # 11-20. EDIT DISTANCE FEATURES
            # Calculate edit distances between consecutive AS paths for each prefix
            edit_distances = []
            edit_distance_dict = defaultdict(list)
            
            for prefix, group in valid_as_paths.groupby('Prefix'):
                if len(group) >= 2:
                    sorted_group = group.sort_values('Timestamp')
                    prev_path = None
                    
                    for _, row in sorted_group.iterrows():
                        current_path = row['AS_Path']
                        
                        if prev_path is not None:
                            dist = calculate_edit_distance(prev_path, current_path)
                            edit_distances.append(dist)
                            edit_distance_dict[prefix].append(dist)
                        
                        prev_path = current_path
            
            if edit_distances:
                # 11. EDIT_DISTANCE_AVG
                features['edit_distance_avg'] = np.mean(edit_distances)
                
                # 12. EDIT_DISTANCE_MAX
                features['edit_distance_max'] = max(edit_distances)
                
                # 13-19. EDIT_DISTANCE_DICT_X (Distribution of edit distances)
                edit_dist_counter = Counter(edit_distances)
                for i in range(7):  # 0 to 6
                    features[f'edit_distance_dict_{i}'] = edit_dist_counter.get(i, 0)
                
                # 20-21. EDIT_DISTANCE_UNIQUE_DICT_X (Distribution of unique edit distances per prefix)
                unique_edit_dists = {}
                for prefix, dists in edit_distance_dict.items():
                    unique_dists = set(dists)
                    for dist in unique_dists:
                        if dist in unique_edit_dists:
                            unique_edit_dists[dist] += 1
                        else:
                            unique_edit_dists[dist] = 1
                
                for i in range(2):  # 0 to 1 for unique distributions
                    features[f'edit_distance_unique_dict_{i}'] = unique_edit_dists.get(i, 0)
            else:
                features['edit_distance_avg'] = 0
                features['edit_distance_max'] = 0
                for i in range(7):
                    features[f'edit_distance_dict_{i}'] = 0
                for i in range(2):
                    features[f'edit_distance_unique_dict_{i}'] = 0
        else:
            features['as_path_max'] = 0
            features['unique_as_path_max'] = 0
            features['edit_distance_avg'] = 0
            features['edit_distance_max'] = 0
            for i in range(7):
                features[f'edit_distance_dict_{i}'] = 0
            for i in range(2):
                features[f'edit_distance_unique_dict_{i}'] = 0
    else:
        features['as_path_max'] = 0
        features['unique_as_path_max'] = 0
        features['edit_distance_avg'] = 0
        features['edit_distance_max'] = 0
        for i in range(7):
            features[f'edit_distance_dict_{i}'] = 0
        for i in range(2):
            features[f'edit_distance_unique_dict_{i}'] = 0
    
    # 22-24. IMPLICIT WITHDRAWAL FEATURES
    if not announcements.empty:
    # Group by prefix and peer to count prefixes with multiple announcements
        prefix_peer_groups = announcements.groupby(['Prefix', 'Peer_IP'])
    
    # Count prefixes with multiple announcements
        imp_wd_prefixes = 0
        imp_wd_spath_prefixes = 0
        imp_wd_dpath_prefixes = 0
    
        for (prefix, peer), group in prefix_peer_groups:
            if len(group) > 1:
            # This prefix has implicit withdrawals
                imp_wd_prefixes += 1
            
            # Check if all AS paths are the same or different
                if 'AS_Path' in group.columns:
                    unique_paths = group['AS_Path'].nunique()
                    if unique_paths == 1:
                    # All announcements have the same AS path
                        imp_wd_spath_prefixes += 1
                    else:
                    # Announcements have different AS paths
                        imp_wd_dpath_prefixes += 1
    
        features['imp_wd'] = imp_wd_prefixes
        features['imp_wd_spath'] = imp_wd_spath_prefixes
        features['imp_wd_dpath'] = imp_wd_dpath_prefixes
    else:
        features['imp_wd'] = 0
        features['imp_wd_spath'] = 0
        features['imp_wd_dpath'] = 0


    # 25-26. RARE AND NEW AS NUMBERS FEATURES
    if not announcements.empty and 'AS_Path' in announcements.columns:
        all_asns = []
    
        # Process each AS_Path
        for as_path in announcements['AS_Path']:
            # Skip null/NaN values
            if pd.isnull(as_path) or as_path == '':
                continue
            
            # Convert to string if it isn't already (just to be safe)
            as_path_str = str(as_path)
        
            # Simple case: Single ASN (e.g. "43289")
            if as_path_str.isdigit():
                all_asns.append(as_path_str)
                continue
            
            # Complex case: Path with multiple ASNs
            # Remove special characters and split by whitespace
            as_path_str = as_path_str.replace('{', '').replace('}', '')
            path_asns = [asn for asn in as_path_str.split() if asn.isdigit()]
            all_asns.extend(path_asns)
    
        # Count the occurrence of each ASN
        asn_counts = Counter(all_asns)
    
        # Define rare ASNs (those appearing less than the threshold)
        rare_threshold = 3
        rare_asns = [asn for asn, count in asn_counts.items() if count < rare_threshold]
    
        # Calculate features
        features['number_rare_ases'] = len(rare_asns)
        features['rare_ases_avg'] = len(rare_asns) / len(all_asns) if all_asns else 0
    else:
        # Default values if no data or AS_Path column
        features['number_rare_ases'] = 0
        features['rare_ases_avg'] = 0
    

        
    # 27-28. FLAP AND NADA FEATURES
    if not df_window.empty:
        # FLAPS: A flap is when a prefix is withdrawn and then announced again
        # Get all prefixes that were both withdrawn and announced in this window
        if not withdrawals.empty and not announcements.empty:
            withdrawn_prefixes = set(withdrawals['Prefix'].dropna())
            announced_prefixes = set(announcements['Prefix'].dropna())
            flapped_prefixes = withdrawn_prefixes.intersection(announced_prefixes)
            features['flaps'] = len(flapped_prefixes)
        else:
            features['flaps'] = 0
        
        # NADAS (Network Attacks and Defenses Assessment)
        # This requires a more complex heuristic to detect potential attack patterns
        # For now, we'll implement a basic heuristic looking at suspicious patterns:
        # 1. Multiple very specific prefixes (e.g., /32) announced in a short window
        # 2. Rapid withdrawal of previously announced prefixes
        
        # Count very specific prefixes (potential DOS indicators)
        very_specific_prefixes = 0
        if 'Prefix' in df_window.columns:
            # Count /32 prefixes which are typical in some DoS attacks
            very_specific_prefixes = sum(1 for prefix in df_window['Prefix'].dropna() 
                                       if isinstance(prefix, str) and prefix.endswith('/32'))
        
        # Ratio of withdrawals to announcements
        wd_ann_ratio = features['withdrawals'] / features['announcements'] if features['announcements'] > 0 else 0
        
        # Basic NADAS score - a simple heuristic
        nadas_score = very_specific_prefixes + (wd_ann_ratio > 0.5) * 10
        features['nadas'] = nadas_score
    else:
        features['flaps'] = 0
        features['nadas'] = 0
    
    # Determine label based on window data
    if 'Label' in df_window.columns:
        labels = df_window['Label'].value_counts()
        if not labels.empty:
            # Choose labeling strategy
            if LABEL_STRATEGY == 'majority':
                # Majority vote
                features['label'] = labels.idxmax()
            elif LABEL_STRATEGY == 'conservative':
                # If any abnormal, label as abnormal
                if any(label != 'normal' for label in labels.index):
                    abnormal_labels = [label for label in labels.index if label != 'normal']
                    features['label'] = abnormal_labels[0]
                else:
                    features['label'] = 'normal'
            elif LABEL_STRATEGY == 'weighted':
                # Weight by count of each label
                total = labels.sum()
                abnormal_weight = sum(count for label, count in labels.items() if label != 'normal') / total
                if abnormal_weight > 0.4:  # Threshold for abnormal classification
                    abnormal_labels = [label for label in labels.index if label != 'normal']
                    features['label'] = abnormal_labels[0] if abnormal_labels else 'normal'
                else:
                    features['label'] = 'normal'
        else:
            features['label'] = 'unknown'
    else:
        features['label'] = 'unknown'
    
    return features

def process_bgp_data():
    """
    Process BGP data file and extract features with specified time window
    """
    print(f"Reading input file: {INPUT_FILE}")
    df = pd.read_csv(INPUT_FILE)
    
    # Convert timestamp to datetime
    df['Timestamp'] = pd.to_datetime(df['Timestamp'])
    
    # Sort by timestamp
    df = df.sort_values('Timestamp')
    
    # Get start and end times
    start_time = df['Timestamp'].min()
    end_time = df['Timestamp'].max()
    
    print(f"Time range: {start_time} to {end_time}")
    
    # Create time windows based on the specified frequency
    window_freq = WINDOW_SIZE
    
    # Use pandas resample to create time windows
    df.set_index('Timestamp', inplace=True)
    
    # Create empty list to store features
    all_features = []
    
    # Group data by time windows
    grouped = df.groupby(pd.Grouper(freq=window_freq))
    
    window_count = 0
    total_windows = len(grouped)
    
    # Process each window
    for window_start, window_df in grouped:
        if not window_df.empty:
            window_df = window_df.reset_index()  # Reset index to get Timestamp as column
            features = extract_features(window_df)
            
            if features:
                window_end = window_start + pd.Timedelta(window_freq)
                features['window_start'] = window_start
                features['window_end'] = window_end
                all_features.append(features)
                window_count += 1
                
                # Print progress
                if window_count % 50 == 0:
                    print(f"Processed {window_count}/{total_windows} windows ({window_count/total_windows:.1%})...")
    
    print(f"Total windows processed: {window_count}")
    
    # Create features dataframe
    if all_features:
        features_df = pd.DataFrame(all_features)
        
        # Ensure all 25 required features are present
        required_features = [
            'dups', 'edit_distance_avg', 'edit_distance_dict_0', 'edit_distance_dict_1',
            'nlri_ann', 'origin_0', 'origin_2', 'imp_wd', 'rare_ases_avg', 'imp_wd_spath',
            'unique_as_path_max', 'edit_distance_dict_2', 'edit_distance_dict_4', 
            'edit_distance_dict_6', 'edit_distance_max', 'edit_distance_unique_dict_0',
            'edit_distance_unique_dict_1', 'announcements', 'origin_changes', 'flaps',
            'nadas', 'number_rare_ases', 'withdrawals', 'as_path_max', 'imp_wd_dpath'
        ]
        
        # Check if all required features are present
        missing_features = [feature for feature in required_features if feature not in features_df.columns]
        if missing_features:
            print(f"Warning: Missing features: {missing_features}")
            # Add missing features with default value 0
            for feature in missing_features:
                features_df[feature] = 0
        
        # Write to output file
        features_df.to_csv(OUTPUT_FILE, index=False)
        print(f"Features written to {OUTPUT_FILE}")
        print(f"Features extracted: {', '.join(features_df.columns)}")
        
        return features_df
    else:
        print("No features extracted. Check input data.")
        return None

# Main execution for Jupyter - uncomment when ready
features_df = process_bgp_data()
# Out:
# Reading input file: /home/smotaali/BGP_Traffic_Generation/results/bgp_updates_analysis_20251208_223239.csv
# /tmp/ipykernel_589631/2368713003.py:353: DtypeWarning: Columns (13) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(INPUT_FILE)
# Time range: 2025-12-08 17:26:21.348996 to 2025-12-09 17:26:35.109632
# Processed 50/86415 windows (0.1%)...
# Processed 100/86415 windows (0.1%)...
# Processed 150/86415 windows (0.2%)...
# Processed 200/86415 windows (0.2%)...
# Processed 250/86415 windows (0.3%)...
# Processed 300/86415 windows (0.3%)...
# Processed 350/86415 windows (0.4%)...
# Processed 400/86415 windows (0.5%)...
# Processed 450/86415 windows (0.5%)...
# Processed 500/86415 windows (0.6%)...
# Processed 550/86415 windows (0.6%)...
# Processed 600/86415 windows (0.7%)...
# Processed 650/86415 windows (0.8%)...
# Processed 700/86415 windows (0.8%)...
# Processed 750/86415 windows (0.9%)...
# Processed 800/86415 windows (0.9%)...
# Processed 850/86415 windows (1.0%)...
# Processed 900/86415 windows (1.0%)...
# Processed 950/86415 windows (1.1%)...
# Processed 1000/86415 windows (1.2%)...
# Processed 1050/86415 windows (1.2%)...
# Processed 1100/86415 windows (1.3%)...
# Processed 1150/86415 windows (1.3%)...
# Processed 1200/86415 windows (1.4%)...
# Processed 1250/86415 windows (1.4%)...
# Processed 1300/86415 windows (1.5%)...
# Processed 1350/86415 windows (1.6%)...
# Processed 1400/86415 windows (1.6%)...
# Processed 1450/86415 windows (1.7%)...
# Processed 1500/86415 windows (1.7%)...
# Processed 1550/86415 windows (1.8%)...
# Processed 1600/86415 windows (1.9%)...
# Processed 1650/86415 windows (1.9%)...
# Processed 1700/86415 windows (2.0%)...
# Processed 1750/86415 windows (2.0%)...
# Processed 1800/86415 windows (2.1%)...
# Processed 1850/86415 windows (2.1%)...
# Processed 1900/86415 windows (2.2%)...
# Processed 1950/86415 windows (2.3%)...
# Processed 2000/86415 windows (2.3%)...
# Processed 2050/86415 windows (2.4%)...
# Processed 2100/86415 windows (2.4%)...
# Processed 2150/86415 windows (2.5%)...
# Processed 2200/86415 windows (2.5%)...
# Processed 2250/86415 windows (2.6%)...
# Processed 2300/86415 windows (2.7%)...
# Processed 2350/86415 windows (2.7%)...
# Processed 2400/86415 windows (2.8%)...
# Processed 2450/86415 windows (2.8%)...
# Processed 2500/86415 windows (2.9%)...
# Processed 2550/86415 windows (3.0%)...
# Processed 2600/86415 windows (3.0%)...
# Processed 2650/86415 windows (3.1%)...
# Processed 2700/86415 windows (3.1%)...
# Processed 2750/86415 windows (3.2%)...
# Processed 2800/86415 windows (3.2%)...
# Processed 2850/86415 windows (3.3%)...
# Processed 2900/86415 windows (3.4%)...
# Processed 2950/86415 windows (3.4%)...
# Processed 3000/86415 windows (3.5%)...
# Processed 3050/86415 windows (3.5%)...
# Processed 3100/86415 windows (3.6%)...
# Processed 3150/86415 windows (3.6%)...
# Processed 3200/86415 windows (3.7%)...
# Processed 3250/86415 windows (3.8%)...
# Processed 3300/86415 windows (3.8%)...
# Processed 3350/86415 windows (3.9%)...
# Processed 3400/86415 windows (3.9%)...
# Processed 3450/86415 windows (4.0%)...
# Processed 3500/86415 windows (4.1%)...
# Processed 3550/86415 windows (4.1%)...
# Processed 3600/86415 windows (4.2%)...
# Processed 3650/86415 windows (4.2%)...
# Processed 3700/86415 windows (4.3%)...
# Processed 3750/86415 windows (4.3%)...
# Processed 3800/86415 windows (4.4%)...
# Processed 3850/86415 windows (4.5%)...
# Processed 3900/86415 windows (4.5%)...
# Processed 3950/86415 windows (4.6%)...
# Processed 4000/86415 windows (4.6%)...
# Processed 4050/86415 windows (4.7%)...
# Processed 4100/86415 windows (4.7%)...
# Processed 4150/86415 windows (4.8%)...
# Processed 4200/86415 windows (4.9%)...
# Processed 4250/86415 windows (4.9%)...
# Processed 4300/86415 windows (5.0%)...
# Processed 4350/86415 windows (5.0%)...
# Processed 4400/86415 windows (5.1%)...
# Processed 4450/86415 windows (5.1%)...
# Processed 4500/86415 windows (5.2%)...
# Processed 4550/86415 windows (5.3%)...
# Processed 4600/86415 windows (5.3%)...
# Processed 4650/86415 windows (5.4%)...
# Processed 4700/86415 windows (5.4%)...
# Processed 4750/86415 windows (5.5%)...
# Processed 4800/86415 windows (5.6%)...
# Processed 4850/86415 windows (5.6%)...
# Processed 4900/86415 windows (5.7%)...
# Processed 4950/86415 windows (5.7%)...
# Processed 5000/86415 windows (5.8%)...
# Processed 5050/86415 windows (5.8%)...
# Processed 5100/86415 windows (5.9%)...
# Processed 5150/86415 windows (6.0%)...
# Processed 5200/86415 windows (6.0%)...
# Processed 5250/86415 windows (6.1%)...
# Processed 5300/86415 windows (6.1%)...
# Processed 5350/86415 windows (6.2%)...
# Processed 5400/86415 windows (6.2%)...
# Processed 5450/86415 windows (6.3%)...
# Processed 5500/86415 windows (6.4%)...
# Processed 5550/86415 windows (6.4%)...
# Processed 5600/86415 windows (6.5%)...
# Processed 5650/86415 windows (6.5%)...
# Processed 5700/86415 windows (6.6%)...
# Processed 5750/86415 windows (6.7%)...
# Processed 5800/86415 windows (6.7%)...
# Processed 5850/86415 windows (6.8%)...
# Processed 5900/86415 windows (6.8%)...
# Processed 5950/86415 windows (6.9%)...
# Processed 6000/86415 windows (6.9%)...
# Processed 6050/86415 windows (7.0%)...
# Processed 6100/86415 windows (7.1%)...
# Processed 6150/86415 windows (7.1%)...
# Processed 6200/86415 windows (7.2%)...
# Processed 6250/86415 windows (7.2%)...
# Processed 6300/86415 windows (7.3%)...
# Processed 6350/86415 windows (7.3%)...
# Processed 6400/86415 windows (7.4%)...
# Processed 6450/86415 windows (7.5%)...
# Processed 6500/86415 windows (7.5%)...
# Processed 6550/86415 windows (7.6%)...
# Processed 6600/86415 windows (7.6%)...
# Processed 6650/86415 windows (7.7%)...
# Processed 6700/86415 windows (7.8%)...
# Processed 6750/86415 windows (7.8%)...
# Processed 6800/86415 windows (7.9%)...
# Processed 6850/86415 windows (7.9%)...
# Processed 6900/86415 windows (8.0%)...
# Processed 6950/86415 windows (8.0%)...
# Processed 7000/86415 windows (8.1%)...
# Processed 7050/86415 windows (8.2%)...
# Processed 7100/86415 windows (8.2%)...
# Processed 7150/86415 windows (8.3%)...
# Processed 7200/86415 windows (8.3%)...
# Processed 7250/86415 windows (8.4%)...
# Processed 7300/86415 windows (8.4%)...
# Processed 7350/86415 windows (8.5%)...
# Processed 7400/86415 windows (8.6%)...
# Processed 7450/86415 windows (8.6%)...
# Processed 7500/86415 windows (8.7%)...
# Processed 7550/86415 windows (8.7%)...
# Processed 7600/86415 windows (8.8%)...
# Processed 7650/86415 windows (8.9%)...
# Processed 7700/86415 windows (8.9%)...
# Processed 7750/86415 windows (9.0%)...
# Processed 7800/86415 windows (9.0%)...
# Processed 7850/86415 windows (9.1%)...
# Processed 7900/86415 windows (9.1%)...
# Processed 7950/86415 windows (9.2%)...
# Processed 8000/86415 windows (9.3%)...
# Processed 8050/86415 windows (9.3%)...
# Processed 8100/86415 windows (9.4%)...
# Processed 8150/86415 windows (9.4%)...
# Processed 8200/86415 windows (9.5%)...
# Processed 8250/86415 windows (9.5%)...
# Processed 8300/86415 windows (9.6%)...
# Processed 8350/86415 windows (9.7%)...
# Processed 8400/86415 windows (9.7%)...
# Processed 8450/86415 windows (9.8%)...
# Processed 8500/86415 windows (9.8%)...
# Processed 8550/86415 windows (9.9%)...
# Processed 8600/86415 windows (10.0%)...
# Processed 8650/86415 windows (10.0%)...
# Processed 8700/86415 windows (10.1%)...
# Processed 8750/86415 windows (10.1%)...
# Processed 8800/86415 windows (10.2%)...
# Processed 8850/86415 windows (10.2%)...
# Processed 8900/86415 windows (10.3%)...
# Processed 8950/86415 windows (10.4%)...
# Processed 9000/86415 windows (10.4%)...
# Processed 9050/86415 windows (10.5%)...
# Processed 9100/86415 windows (10.5%)...
# Processed 9150/86415 windows (10.6%)...
# Processed 9200/86415 windows (10.6%)...
# Processed 9250/86415 windows (10.7%)...
# Processed 9300/86415 windows (10.8%)...
# Processed 9350/86415 windows (10.8%)...
# Processed 9400/86415 windows (10.9%)...
# Processed 9450/86415 windows (10.9%)...
# Processed 9500/86415 windows (11.0%)...
# Processed 9550/86415 windows (11.1%)...
# Processed 9600/86415 windows (11.1%)...
# Processed 9650/86415 windows (11.2%)...
# Processed 9700/86415 windows (11.2%)...
# Processed 9750/86415 windows (11.3%)...
# Processed 9800/86415 windows (11.3%)...
# Processed 9850/86415 windows (11.4%)...
# Processed 9900/86415 windows (11.5%)...
# Processed 9950/86415 windows (11.5%)...
# Processed 10000/86415 windows (11.6%)...
# Processed 10050/86415 windows (11.6%)...
# Processed 10100/86415 windows (11.7%)...
# Processed 10150/86415 windows (11.7%)...
# Processed 10200/86415 windows (11.8%)...
# Processed 10250/86415 windows (11.9%)...
# Processed 10300/86415 windows (11.9%)...
# Processed 10350/86415 windows (12.0%)...
# Processed 10400/86415 windows (12.0%)...
# Processed 10450/86415 windows (12.1%)...
# Processed 10500/86415 windows (12.2%)...
# Processed 10550/86415 windows (12.2%)...
# Processed 10600/86415 windows (12.3%)...
# Processed 10650/86415 windows (12.3%)...
# Processed 10700/86415 windows (12.4%)...
# Processed 10750/86415 windows (12.4%)...
# Processed 10800/86415 windows (12.5%)...
# Processed 10850/86415 windows (12.6%)...
# Processed 10900/86415 windows (12.6%)...
# Processed 10950/86415 windows (12.7%)...
# Processed 11000/86415 windows (12.7%)...
# Processed 11050/86415 windows (12.8%)...
# Processed 11100/86415 windows (12.8%)...
# Processed 11150/86415 windows (12.9%)...
# Processed 11200/86415 windows (13.0%)...
# Processed 11250/86415 windows (13.0%)...
# Processed 11300/86415 windows (13.1%)...
# Processed 11350/86415 windows (13.1%)...
# Processed 11400/86415 windows (13.2%)...
# Processed 11450/86415 windows (13.3%)...
# Processed 11500/86415 windows (13.3%)...
# Processed 11550/86415 windows (13.4%)...
# Processed 11600/86415 windows (13.4%)...
# Processed 11650/86415 windows (13.5%)...
# Processed 11700/86415 windows (13.5%)...
# Processed 11750/86415 windows (13.6%)...
# Processed 11800/86415 windows (13.7%)...
# Processed 11850/86415 windows (13.7%)...
# Processed 11900/86415 windows (13.8%)...
# Processed 11950/86415 windows (13.8%)...
# Processed 12000/86415 windows (13.9%)...
# Processed 12050/86415 windows (13.9%)...
# Processed 12100/86415 windows (14.0%)...
# Processed 12150/86415 windows (14.1%)...
# Processed 12200/86415 windows (14.1%)...
# Processed 12250/86415 windows (14.2%)...
# Processed 12300/86415 windows (14.2%)...
# Processed 12350/86415 windows (14.3%)...
# Processed 12400/86415 windows (14.3%)...
# Processed 12450/86415 windows (14.4%)...
# Processed 12500/86415 windows (14.5%)...
# Processed 12550/86415 windows (14.5%)...
# Processed 12600/86415 windows (14.6%)...
# Processed 12650/86415 windows (14.6%)...
# Processed 12700/86415 windows (14.7%)...
# Processed 12750/86415 windows (14.8%)...
# Processed 12800/86415 windows (14.8%)...
# Processed 12850/86415 windows (14.9%)...
# Processed 12900/86415 windows (14.9%)...
# Processed 12950/86415 windows (15.0%)...
# Processed 13000/86415 windows (15.0%)...
# Processed 13050/86415 windows (15.1%)...
# Processed 13100/86415 windows (15.2%)...
# Processed 13150/86415 windows (15.2%)...
# Processed 13200/86415 windows (15.3%)...
# Processed 13250/86415 windows (15.3%)...
# Processed 13300/86415 windows (15.4%)...
# Processed 13350/86415 windows (15.4%)...
# Processed 13400/86415 windows (15.5%)...
# Processed 13450/86415 windows (15.6%)...
# Processed 13500/86415 windows (15.6%)...
# Processed 13550/86415 windows (15.7%)...
# Processed 13600/86415 windows (15.7%)...
# Processed 13650/86415 windows (15.8%)...
# Processed 13700/86415 windows (15.9%)...
# Processed 13750/86415 windows (15.9%)...
# Processed 13800/86415 windows (16.0%)...
# Processed 13850/86415 windows (16.0%)...
# Processed 13900/86415 windows (16.1%)...
# Processed 13950/86415 windows (16.1%)...
# Processed 14000/86415 windows (16.2%)...
# Processed 14050/86415 windows (16.3%)...
# Processed 14100/86415 windows (16.3%)...
# Processed 14150/86415 windows (16.4%)...
# Processed 14200/86415 windows (16.4%)...
# Processed 14250/86415 windows (16.5%)...
# Processed 14300/86415 windows (16.5%)...
# Processed 14350/86415 windows (16.6%)...
# Processed 14400/86415 windows (16.7%)...
# Processed 14450/86415 windows (16.7%)...
# Processed 14500/86415 windows (16.8%)...
# Processed 14550/86415 windows (16.8%)...
# Processed 14600/86415 windows (16.9%)...
# Processed 14650/86415 windows (17.0%)...
# Processed 14700/86415 windows (17.0%)...
# Processed 14750/86415 windows (17.1%)...
# Processed 14800/86415 windows (17.1%)...
# Processed 14850/86415 windows (17.2%)...
# Processed 14900/86415 windows (17.2%)...
# Processed 14950/86415 windows (17.3%)...
# Processed 15000/86415 windows (17.4%)...
# Processed 15050/86415 windows (17.4%)...
# Processed 15100/86415 windows (17.5%)...
# Processed 15150/86415 windows (17.5%)...
# Processed 15200/86415 windows (17.6%)...
# Processed 15250/86415 windows (17.6%)...
# Processed 15300/86415 windows (17.7%)...
# Processed 15350/86415 windows (17.8%)...
# Processed 15400/86415 windows (17.8%)...
# Processed 15450/86415 windows (17.9%)...
# Processed 15500/86415 windows (17.9%)...
# Processed 15550/86415 windows (18.0%)...
# Processed 15600/86415 windows (18.1%)...
# Processed 15650/86415 windows (18.1%)...
# Processed 15700/86415 windows (18.2%)...
# Processed 15750/86415 windows (18.2%)...
# Processed 15800/86415 windows (18.3%)...
# Processed 15850/86415 windows (18.3%)...
# Processed 15900/86415 windows (18.4%)...
# Processed 15950/86415 windows (18.5%)...
# Processed 16000/86415 windows (18.5%)...
# Processed 16050/86415 windows (18.6%)...
# Processed 16100/86415 windows (18.6%)...
# Processed 16150/86415 windows (18.7%)...
# Processed 16200/86415 windows (18.7%)...
# Processed 16250/86415 windows (18.8%)...
# Processed 16300/86415 windows (18.9%)...
# Processed 16350/86415 windows (18.9%)...
# Processed 16400/86415 windows (19.0%)...
# Processed 16450/86415 windows (19.0%)...
# Processed 16500/86415 windows (19.1%)...
# Processed 16550/86415 windows (19.2%)...
# Processed 16600/86415 windows (19.2%)...
# Processed 16650/86415 windows (19.3%)...
# Processed 16700/86415 windows (19.3%)...
# Processed 16750/86415 windows (19.4%)...
# Processed 16800/86415 windows (19.4%)...
# Processed 16850/86415 windows (19.5%)...
# Processed 16900/86415 windows (19.6%)...
# Processed 16950/86415 windows (19.6%)...
# Processed 17000/86415 windows (19.7%)...
# Processed 17050/86415 windows (19.7%)...
# Processed 17100/86415 windows (19.8%)...
# Processed 17150/86415 windows (19.8%)...
# Processed 17200/86415 windows (19.9%)...
# Processed 17250/86415 windows (20.0%)...
# Processed 17300/86415 windows (20.0%)...
# Processed 17350/86415 windows (20.1%)...
# Processed 17400/86415 windows (20.1%)...
# Processed 17450/86415 windows (20.2%)...
# Processed 17500/86415 windows (20.3%)...
# Processed 17550/86415 windows (20.3%)...
# Processed 17600/86415 windows (20.4%)...
# Processed 17650/86415 windows (20.4%)...
# Processed 17700/86415 windows (20.5%)...
# Processed 17750/86415 windows (20.5%)...
# Processed 17800/86415 windows (20.6%)...
# Processed 17850/86415 windows (20.7%)...
# Processed 17900/86415 windows (20.7%)...
# Processed 17950/86415 windows (20.8%)...
# Processed 18000/86415 windows (20.8%)...
# Processed 18050/86415 windows (20.9%)...
# Processed 18100/86415 windows (20.9%)...
# Processed 18150/86415 windows (21.0%)...
# Processed 18200/86415 windows (21.1%)...
# Processed 18250/86415 windows (21.1%)...
# Processed 18300/86415 windows (21.2%)...
# Processed 18350/86415 windows (21.2%)...
# Processed 18400/86415 windows (21.3%)...
# Processed 18450/86415 windows (21.4%)...
# Processed 18500/86415 windows (21.4%)...
# Processed 18550/86415 windows (21.5%)...
# Processed 18600/86415 windows (21.5%)...
# Processed 18650/86415 windows (21.6%)...
# Processed 18700/86415 windows (21.6%)...
# Processed 18750/86415 windows (21.7%)...
# Processed 18800/86415 windows (21.8%)...
# Processed 18850/86415 windows (21.8%)...
# Processed 18900/86415 windows (21.9%)...
# Processed 18950/86415 windows (21.9%)...
# Processed 19000/86415 windows (22.0%)...
# Processed 19050/86415 windows (22.0%)...
# Processed 19100/86415 windows (22.1%)...
# Processed 19150/86415 windows (22.2%)...
# Processed 19200/86415 windows (22.2%)...
# Processed 19250/86415 windows (22.3%)...
# Processed 19300/86415 windows (22.3%)...
# Processed 19350/86415 windows (22.4%)...
# Processed 19400/86415 windows (22.4%)...
# Processed 19450/86415 windows (22.5%)...
# Processed 19500/86415 windows (22.6%)...
# Processed 19550/86415 windows (22.6%)...
# Processed 19600/86415 windows (22.7%)...
# Processed 19650/86415 windows (22.7%)...
# Processed 19700/86415 windows (22.8%)...
# Processed 19750/86415 windows (22.9%)...
# Processed 19800/86415 windows (22.9%)...
# Processed 19850/86415 windows (23.0%)...
# Processed 19900/86415 windows (23.0%)...
# Processed 19950/86415 windows (23.1%)...
# Processed 20000/86415 windows (23.1%)...
# Processed 20050/86415 windows (23.2%)...
# Processed 20100/86415 windows (23.3%)...
# Processed 20150/86415 windows (23.3%)...
# Processed 20200/86415 windows (23.4%)...
# Processed 20250/86415 windows (23.4%)...
# Processed 20300/86415 windows (23.5%)...
# Processed 20350/86415 windows (23.5%)...
# Processed 20400/86415 windows (23.6%)...
# Processed 20450/86415 windows (23.7%)...
# Processed 20500/86415 windows (23.7%)...
# Processed 20550/86415 windows (23.8%)...
# Processed 20600/86415 windows (23.8%)...
# Processed 20650/86415 windows (23.9%)...
# Processed 20700/86415 windows (24.0%)...
# Processed 20750/86415 windows (24.0%)...
# Processed 20800/86415 windows (24.1%)...
# Processed 20850/86415 windows (24.1%)...
# Processed 20900/86415 windows (24.2%)...
# Processed 20950/86415 windows (24.2%)...
# Processed 21000/86415 windows (24.3%)...
# Processed 21050/86415 windows (24.4%)...
# Processed 21100/86415 windows (24.4%)...
# Processed 21150/86415 windows (24.5%)...
# Processed 21200/86415 windows (24.5%)...
# Processed 21250/86415 windows (24.6%)...
# Processed 21300/86415 windows (24.6%)...
# Processed 21350/86415 windows (24.7%)...
# Processed 21400/86415 windows (24.8%)...
# Processed 21450/86415 windows (24.8%)...
# Processed 21500/86415 windows (24.9%)...
# Processed 21550/86415 windows (24.9%)...
# Processed 21600/86415 windows (25.0%)...
# Processed 21650/86415 windows (25.1%)...
# Processed 21700/86415 windows (25.1%)...
# Processed 21750/86415 windows (25.2%)...
# Processed 21800/86415 windows (25.2%)...
# Processed 21850/86415 windows (25.3%)...
# Processed 21900/86415 windows (25.3%)...
# Processed 21950/86415 windows (25.4%)...
# Processed 22000/86415 windows (25.5%)...
# Processed 22050/86415 windows (25.5%)...
# Processed 22100/86415 windows (25.6%)...
# Processed 22150/86415 windows (25.6%)...
# Processed 22200/86415 windows (25.7%)...
# Processed 22250/86415 windows (25.7%)...
# Processed 22300/86415 windows (25.8%)...
# Processed 22350/86415 windows (25.9%)...
# Processed 22400/86415 windows (25.9%)...
# Processed 22450/86415 windows (26.0%)...
# Processed 22500/86415 windows (26.0%)...
# Processed 22550/86415 windows (26.1%)...
# Processed 22600/86415 windows (26.2%)...
# Processed 22650/86415 windows (26.2%)...
# Processed 22700/86415 windows (26.3%)...
# Processed 22750/86415 windows (26.3%)...
# Processed 22800/86415 windows (26.4%)...
# Processed 22850/86415 windows (26.4%)...
# Processed 22900/86415 windows (26.5%)...
# Processed 22950/86415 windows (26.6%)...
# Processed 23000/86415 windows (26.6%)...
# Processed 23050/86415 windows (26.7%)...
# Processed 23100/86415 windows (26.7%)...
# Processed 23150/86415 windows (26.8%)...
# Processed 23200/86415 windows (26.8%)...
# Processed 23250/86415 windows (26.9%)...
# Processed 23300/86415 windows (27.0%)...
# Processed 23350/86415 windows (27.0%)...
# Processed 23400/86415 windows (27.1%)...
# Processed 23450/86415 windows (27.1%)...
# Processed 23500/86415 windows (27.2%)...
# Processed 23550/86415 windows (27.3%)...
# Processed 23600/86415 windows (27.3%)...
# Processed 23650/86415 windows (27.4%)...
# Processed 23700/86415 windows (27.4%)...
# Processed 23750/86415 windows (27.5%)...
# Processed 23800/86415 windows (27.5%)...
# Processed 23850/86415 windows (27.6%)...
# Processed 23900/86415 windows (27.7%)...
# Processed 23950/86415 windows (27.7%)...
# Processed 24000/86415 windows (27.8%)...
# Processed 24050/86415 windows (27.8%)...
# Processed 24100/86415 windows (27.9%)...
# Processed 24150/86415 windows (27.9%)...
# Processed 24200/86415 windows (28.0%)...
# Processed 24250/86415 windows (28.1%)...
# Processed 24300/86415 windows (28.1%)...
# Processed 24350/86415 windows (28.2%)...
# Processed 24400/86415 windows (28.2%)...
# Processed 24450/86415 windows (28.3%)...
# Processed 24500/86415 windows (28.4%)...
# Processed 24550/86415 windows (28.4%)...
# Processed 24600/86415 windows (28.5%)...
# Processed 24650/86415 windows (28.5%)...
# Processed 24700/86415 windows (28.6%)...
# Processed 24750/86415 windows (28.6%)...
# Processed 24800/86415 windows (28.7%)...
# Processed 24850/86415 windows (28.8%)...
# Processed 24900/86415 windows (28.8%)...
# Processed 24950/86415 windows (28.9%)...
# Processed 25000/86415 windows (28.9%)...
# Processed 25050/86415 windows (29.0%)...
# Processed 25100/86415 windows (29.0%)...
# Processed 25150/86415 windows (29.1%)...
# Processed 25200/86415 windows (29.2%)...
# Processed 25250/86415 windows (29.2%)...
# Processed 25300/86415 windows (29.3%)...
# Processed 25350/86415 windows (29.3%)...
# Processed 25400/86415 windows (29.4%)...
# Processed 25450/86415 windows (29.5%)...
# Processed 25500/86415 windows (29.5%)...
# Processed 25550/86415 windows (29.6%)...
# Processed 25600/86415 windows (29.6%)...
# Processed 25650/86415 windows (29.7%)...
# Processed 25700/86415 windows (29.7%)...
# Processed 25750/86415 windows (29.8%)...
# Processed 25800/86415 windows (29.9%)...
# Processed 25850/86415 windows (29.9%)...
# Processed 25900/86415 windows (30.0%)...
# Processed 25950/86415 windows (30.0%)...
# Processed 26000/86415 windows (30.1%)...
# Processed 26050/86415 windows (30.1%)...
# Processed 26100/86415 windows (30.2%)...
# Processed 26150/86415 windows (30.3%)...
# Processed 26200/86415 windows (30.3%)...
# Processed 26250/86415 windows (30.4%)...
# Processed 26300/86415 windows (30.4%)...
# Processed 26350/86415 windows (30.5%)...
# Processed 26400/86415 windows (30.6%)...
# Processed 26450/86415 windows (30.6%)...
# Processed 26500/86415 windows (30.7%)...
# Processed 26550/86415 windows (30.7%)...
# Processed 26600/86415 windows (30.8%)...
# Processed 26650/86415 windows (30.8%)...
# Processed 26700/86415 windows (30.9%)...
# Processed 26750/86415 windows (31.0%)...
# Processed 26800/86415 windows (31.0%)...
# Processed 26850/86415 windows (31.1%)...
# Processed 26900/86415 windows (31.1%)...
# Processed 26950/86415 windows (31.2%)...
# Processed 27000/86415 windows (31.2%)...
# Processed 27050/86415 windows (31.3%)...
# Processed 27100/86415 windows (31.4%)...
# Processed 27150/86415 windows (31.4%)...
# Processed 27200/86415 windows (31.5%)...
# Processed 27250/86415 windows (31.5%)...
# Processed 27300/86415 windows (31.6%)...
# Processed 27350/86415 windows (31.6%)...
# Processed 27400/86415 windows (31.7%)...
# Processed 27450/86415 windows (31.8%)...
# Processed 27500/86415 windows (31.8%)...
# Processed 27550/86415 windows (31.9%)...
# Processed 27600/86415 windows (31.9%)...
# Processed 27650/86415 windows (32.0%)...
# Processed 27700/86415 windows (32.1%)...
# Processed 27750/86415 windows (32.1%)...
# Processed 27800/86415 windows (32.2%)...
# Processed 27850/86415 windows (32.2%)...
# Processed 27900/86415 windows (32.3%)...
# Processed 27950/86415 windows (32.3%)...
# Processed 28000/86415 windows (32.4%)...
# Processed 28050/86415 windows (32.5%)...
# Processed 28100/86415 windows (32.5%)...
# Processed 28150/86415 windows (32.6%)...
# Processed 28200/86415 windows (32.6%)...
# Processed 28250/86415 windows (32.7%)...
# Processed 28300/86415 windows (32.7%)...
# Processed 28350/86415 windows (32.8%)...
# Processed 28400/86415 windows (32.9%)...
# Processed 28450/86415 windows (32.9%)...
# Processed 28500/86415 windows (33.0%)...
# Processed 28550/86415 windows (33.0%)...
# Processed 28600/86415 windows (33.1%)...
# Processed 28650/86415 windows (33.2%)...
# Processed 28700/86415 windows (33.2%)...
# Processed 28750/86415 windows (33.3%)...
# Processed 28800/86415 windows (33.3%)...
# Processed 28850/86415 windows (33.4%)...
# Processed 28900/86415 windows (33.4%)...
# Processed 28950/86415 windows (33.5%)...
# Processed 29000/86415 windows (33.6%)...
# Processed 29050/86415 windows (33.6%)...
# Processed 29100/86415 windows (33.7%)...
# Processed 29150/86415 windows (33.7%)...
# Processed 29200/86415 windows (33.8%)...
# Processed 29250/86415 windows (33.8%)...
# Processed 29300/86415 windows (33.9%)...
# Processed 29350/86415 windows (34.0%)...
# Processed 29400/86415 windows (34.0%)...
# Processed 29450/86415 windows (34.1%)...
# Processed 29500/86415 windows (34.1%)...
# Total windows processed: 29527
# Features written to /home/smotaali/BGP_Traffic_Generation/results/20251208_223239_exctracted_1s.csv
# Features extracted: announcements, withdrawals, nlri_ann, dups, origin_0, origin_2, origin_changes, as_path_max, unique_as_path_max, edit_distance_avg, edit_distance_max, edit_distance_dict_0, edit_distance_dict_1, edit_distance_dict_2, edit_distance_dict_3, edit_distance_dict_4, edit_distance_dict_5, edit_distance_dict_6, edit_distance_unique_dict_0, edit_distance_unique_dict_1, imp_wd, imp_wd_spath, imp_wd_dpath, number_rare_ases, rare_ases_avg, flaps, nadas, label, window_start, window_end
